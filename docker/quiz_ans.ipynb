# %% [markdown]
# ## Welcome to GCDS

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification

import random
random.seed(1337)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ce02f4143742> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.datasets import make_classification
#       4
#       5 import random
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## Instruction
# Please go through question listed below (adding new cells if required), please provide comments to justify your models

# %% [markdown]
# ## A. Classification

# %%
# creating a classification model with 2 classes and 2 features
X, y = make_classification(n_samples= 200, n_classes=2, n_features=2, 
                           n_redundant = 0, n_informative = 2,
                           n_clusters_per_class = 2, 
                           weights = (0.95, 0.05))

# %% [markdown]
# **Q1.** The above code creates a biased dataset with 2 classes. Please visualise the classes using scatter plot below.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt


fig, ax = plt.subplots()
fig.set_size_inches(10.5, 5.5)

X_n = X[np.where(y==0)]
X_p = X[np.where(y==1)]

ax.scatter(x = X_p[:,0], y = X_p[:,1], c='r', alpha = 0.5, label='p')
ax.scatter(x = X_n[:,0], y = X_n[:,1], c='g', alpha = 0.5, label='n')
ax.set_title('sample 2 dimension dataset')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.legend()

# %% [markdown]
# **Q2.** Write a supervised classification model to predict the *minority class*

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# pipeline 
svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("linear_scv", SVC())
])

# fit
svm_clf.fit(X_train, y_train)

# is accuracy a good score?
cross_val_score(svm_clf, X_train, y_train, cv=5, scoring = 'accuracy')

# generate confusion matrix 
confusion_matrix(y_test, svm_clf.predict(X_test))
# Out:
# array([[64,  0],
#        [ 1,  1]])

# %% [markdown]
# **Q3.** Treating records in the *minority class* as anomalies,  please write an anomaly detection/unsupervised model to detect those records.

# %%
from sklearn.ensemble import IsolationForest
clf = IsolationForest(random_state=0)
outliers = clf.fit_predict(X)

# %% [markdown]
# **Q4.** Visualise anomalies detect on scatter plot from Q1

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

fig, ax = plt.subplots()
fig.set_size_inches(10.5, 5.5)

X_n = X[np.where(y==0)]
X_o = X[np.where(outliers==-1)]
X_p = X[np.where(y==1)]

ax.scatter(x = X_p[:,0], y = X_p[:,1], c='r', alpha = 1, s = 200, label='p')
ax.scatter(x = X_n[:,0], y = X_n[:,1], c='g', alpha = 0.5, s = 200, label='n')
ax.scatter(x = X_o[:,0], y = X_o[:,1], c='b', alpha = 0.5, label='outliers')
ax.set_title(f"sample 2 dimension dataset, with anomalies")
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.legend()

# %% [markdown]
# ## B. Computer Science

# %%
x = np.random.randint(1000, size = 1000)

# %% [markdown]
# **Q5.** Given above arrange with 1000 random number, implement a sorting algorithm.

# %%
def insertionSort(arr): 
    # Traverse through 1 to len(arr) 
    for i in range(1, len(arr)): 
        key = arr[i] 
  
        # Move elements of arr[0..i-1], that are 
        # greater than key, to one position ahead 
        # of their current position 
        j = i-1
        while j >= 0 and key < arr[j] : 
                arr[j + 1] = arr[j] 
                j -= 1
        arr[j + 1] = key 

insertionSort(x)
x
# Out:
# array([  0,   2,   3,   3,   4,   5,   5,   6,   6,   7,   8,   8,  10,
#         12,  13,  13,  14,  17,  18,  19,  19,  19,  22,  23,  23,  23,
#         25,  26,  26,  29,  29,  30,  31,  32,  32,  32,  33,  33,  33,
#         35,  36,  38,  38,  40,  40,  41,  42,  43,  44,  44,  45,  45,
#         47,  48,  49,  49,  51,  52,  52,  53,  54,  54,  54,  55,  57,
#         58,  59,  62,  64,  64,  67,  67,  68,  70,  70,  70,  70,  70,
#         71,  71,  73,  74,  75,  76,  76,  77,  77,  78,  78,  79,  83,
#         84,  84,  88,  90,  93,  93,  93,  95,  96,  96,  98, 100, 103,
#        103, 104, 105, 105, 106, 107, 107, 107, 108, 110, 110, 111, 111,
#        111, 112, 112, 113, 114, 116, 116, 117, 119, 119, 119, 119, 120,
#        120, 120, 121, 122, 122, 123, 126, 127, 128, 128, 130, 130, 130,
#        131, 131, 132, 133, 138, 139, 141, 141, 146, 147, 147, 147, 147,
#        148, 149, 150, 152, 152, 153, 153, 153, 154, 154, 156, 156, 156,
#        157, 158, 158, 161, 161, 161, 163, 166, 166, 167, 168, 168, 170,
#        170, 171, 172, 172, 173, 174, 175, 175, 176, 177, 178, 179, 181,
#        181, 181, 181, 183, 184, 184, 184, 185, 186, 186, 190, 192, 192,
#        192, 193, 193, 194, 194, 197, 199, 200, 201, 201, 202, 202, 202,
#        203, 203, 205, 208, 208, 208, 210, 210, 211, 215, 216, 217, 219,
#        219, 220, 220, 221, 221, 223, 223, 223, 224, 224, 224, 225, 225,
#        227, 228, 228, 229, 229, 231, 232, 234, 237, 239, 240, 240, 240,
#        242, 242, 242, 245, 247, 248, 248, 250, 251, 251, 251, 253, 254,
#        256, 257, 257, 257, 258, 259, 260, 261, 261, 263, 264, 265, 265,
#        267, 269, 270, 272, 273, 276, 278, 279, 279, 280, 281, 281, 282,
#        283, 283, 283, 284, 285, 285, 285, 286, 292, 292, 292, 294, 296,
#        299, 299, 299, 300, 301, 303, 304, 305, 305, 307, 308, 310, 311,
#        311, 312, 313, 313, 313, 317, 319, 319, 319, 320, 321, 322, 322,
#        323, 324, 324, 324, 327, 328, 329, 330, 331, 331, 332, 333, 333,
#        334, 336, 337, 338, 338, 340, 342, 343, 345, 346, 347, 347, 347,
#        349, 351, 352, 353, 354, 355, 355, 359, 359, 361, 361, 362, 363,
#        365, 365, 366, 366, 366, 368, 369, 369, 370, 370, 371, 372, 373,
#        375, 376, 376, 376, 376, 381, 381, 382, 383, 384, 384, 386, 386,
#        387, 387, 388, 390, 390, 391, 391, 391, 392, 392, 395, 396, 398,
#        399, 399, 399, 401, 402, 403, 404, 405, 406, 407, 408, 409, 409,
#        411, 411, 412, 413, 413, 414, 416, 417, 418, 419, 419, 419, 420,
#        420, 421, 421, 421, 422, 424, 426, 427, 427, 430, 431, 431, 433,
#        433, 435, 435, 436, 436, 437, 438, 440, 443, 443, 445, 446, 447,
#        447, 448, 449, 449, 450, 450, 450, 451, 452, 453, 454, 454, 456,
#        457, 457, 457, 457, 458, 463, 464, 464, 465, 466, 467, 469, 471,
#        472, 472, 473, 474, 474, 476, 476, 478, 480, 483, 484, 487, 487,
#        487, 489, 492, 492, 493, 493, 493, 494, 496, 496, 497, 497, 498,
#        498, 500, 500, 500, 500, 502, 504, 506, 507, 507, 509, 510, 511,
#        515, 518, 520, 521, 521, 523, 523, 524, 524, 525, 526, 528, 528,
#        530, 531, 533, 534, 535, 538, 539, 539, 539, 542, 543, 543, 544,
#        545, 547, 548, 549, 549, 550, 550, 552, 556, 557, 558, 558, 559,
#        559, 560, 561, 564, 565, 567, 567, 569, 571, 573, 573, 577, 578,
#        578, 578, 579, 581, 581, 582, 583, 583, 584, 585, 585, 585, 587,
#        589, 590, 591, 593, 595, 598, 599, 600, 600, 600, 601, 601, 601,
#        601, 602, 602, 602, 604, 606, 606, 606, 609, 610, 611, 611, 611,
#        613, 613, 614, 615, 615, 616, 618, 620, 622, 624, 624, 625, 626,
#        628, 629, 630, 632, 632, 633, 633, 634, 634, 635, 637, 637, 639,
#        639, 641, 641, 642, 645, 645, 645, 646, 646, 647, 647, 647, 647,
#        649, 650, 650, 652, 654, 658, 658, 659, 660, 662, 662, 665, 665,
#        667, 667, 668, 669, 671, 671, 671, 671, 677, 679, 679, 679, 681,
#        684, 688, 689, 689, 693, 693, 693, 693, 694, 694, 696, 697, 697,
#        699, 699, 699, 700, 700, 702, 702, 703, 703, 704, 705, 706, 706,
#        707, 708, 709, 709, 710, 712, 713, 714, 714, 715, 716, 717, 721,
#        721, 721, 721, 722, 723, 723, 723, 723, 725, 726, 728, 734, 735,
#        735, 737, 738, 738, 740, 742, 742, 743, 744, 747, 748, 749, 749,
#        750, 750, 751, 751, 751, 752, 755, 756, 756, 757, 758, 758, 759,
#        762, 763, 764, 764, 765, 767, 767, 768, 768, 769, 769, 769, 769,
#        770, 771, 772, 774, 776, 776, 776, 779, 780, 781, 781, 782, 783,
#        783, 785, 785, 786, 790, 791, 793, 793, 794, 796, 796, 797, 800,
#        801, 802, 804, 805, 805, 806, 808, 810, 811, 812, 812, 812, 814,
#        815, 816, 816, 816, 817, 818, 818, 821, 823, 824, 824, 824, 825,
#        825, 827, 829, 830, 830, 831, 832, 835, 835, 835, 836, 836, 837,
#        839, 840, 841, 841, 842, 844, 846, 847, 847, 847, 848, 849, 849,
#        850, 851, 851, 851, 854, 855, 857, 857, 857, 858, 859, 861, 862,
#        862, 863, 863, 864, 867, 869, 869, 869, 871, 872, 874, 876, 879,
#        882, 883, 883, 883, 884, 884, 884, 886, 886, 887, 889, 890, 890,
#        891, 891, 891, 892, 892, 893, 895, 895, 896, 896, 896, 897, 897,
#        898, 905, 905, 905, 906, 908, 911, 912, 915, 917, 917, 919, 919,
#        920, 922, 925, 925, 926, 927, 928, 929, 929, 929, 932, 932, 934,
#        934, 934, 938, 939, 939, 939, 940, 942, 942, 942, 943, 946, 947,
#        948, 949, 950, 953, 953, 953, 954, 955, 956, 959, 960, 960, 962,
#        963, 963, 964, 965, 965, 965, 966, 966, 966, 968, 968, 968, 969,
#        971, 972, 973, 975, 975, 976, 976, 977, 978, 981, 981, 982, 982,
#        986, 987, 988, 989, 992, 992, 993, 995, 996, 997, 997, 999])

# %% [markdown]
# **Q6.** what is the computation complexity of above code?

# %% [markdown]
# $O(n*2)$
